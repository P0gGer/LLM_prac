# %%
from llama_index.openai import OpenAI #OpenAI LLM모델을 불러온다
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from llama_index.openai import OpenAI #OpenAI LLM모델을 불러온다
#
# ModuleNotFoundError: No module named 'llama_index.openai'

# %%
import os
from dotenv import load_dotenv

# %%
# 문서 로드 및 인덱스
from llama_index import SimpleDirectoryReader, GPTListIndex
